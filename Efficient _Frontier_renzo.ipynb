# %% [markdown]
# # Efficient Frontiner from Modern Portfolio Theory implemented in Python

# %% [markdown]
# ## Modern Portfolio Theory

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import scipy.optimize as sco
from Get_Stocks import*
from EF import PortfolioOptimization
plt.style.use('fivethirtyeight')
np.random.seed(777)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# #Efectuamos los inputs de los parametros que las funciones van a recibir

# n_cotizacion = int(input("Ingrese el número de años de cotización a filtrar: "))
# precio_max = int(input("Ingrese el precio máximo por el cual quiere filtrar: "))
# precio_min = int(input("Ingrese el precio mínimo por el cual quiere filtrar: "))
# beta_max = float(input("Ingrese el beta máximo por el cual quiere filtrar: "))

# %%
# stock_filter = StockFilter()

# # Call the methods on the instance
# data = down_stocks()
# # data = stock_filter.filtro_betas(data,'betas_file.csv',beta_max)
# data = stock_filter.filtro_nulo(data)
# data = stock_filter.filtro_tiempo(data,n_cotizacion)
# data = stock_filter.filtro_precio(data,precio_max, precio_min)

# table = data

# %%
stocks = ['AAPL', 'GOOGL', 'MSFT', 'AMZN', 'META', 'TSLA', 'NVDA', 'JPM', 'V', 'JNJ', 'BABA', 'WMT', 'PG', 'MA', 'UNH', 'DIS', 'HD', 'PYPL', 'CMCSA', 'VZ', 'ADBE', 'NFLX', 'INTC', 'PFE', 'CRM', 'BAC', 'T', 'ABBV', 'XOM', 'KO', 'CVX', 'CSCO', 'PEP', 'TMO', 'NKE', 'MRK', 'ABT', 'WFC', 'WBA', 'ORCL', 'AMGN', 'MCD', 'MDT', 'HON', 'IBM', 'COST', 'TXN', 'MMM', 'ACN', 'BA', 'LLY']

data = yf.download(stocks, start = '2010-01-01')['Adj Close']
table = data
# Out:
# [*********************100%***********************]  51 of 51 completed

# %%
table
# Out:
#                   AAPL        ABBV         ABT         ACN        ADBE  \
# Date
# 2010-01-04    6.496294         NaN   19.336395   32.708153   37.090000
# 2010-01-05    6.507524         NaN   19.180180   32.910301   37.700001
# 2010-01-06    6.404014         NaN   19.286695   33.260159   37.619999
# 2010-01-07    6.392176         NaN   19.446470   33.229065   36.889999
# 2010-01-08    6.434672         NaN   19.545891   33.096886   36.689999
# ...                ...         ...         ...         ...         ...
# 2023-06-12  183.789993  137.729996  101.400002  311.480011  474.630005
# 2023-06-13  183.309998  138.309998  101.860001  315.160004  478.989990
# 2023-06-14  183.949997  136.229996  103.250000  315.049988  479.529999
# 2023-06-15  186.009995  135.889999  105.019997  323.769989  490.910004
# 2023-06-16  184.919998  138.639999  106.199997  319.540009  495.179993
#
#                   AMGN        AMZN          BA       BABA        BAC  ...  \
# ...

# %%
# symbols = list(table.head(0))
noa = len(stocks)
# symbols[:]

# %%
# Assuming you have the necessary inputs:
log_returns = np.log(table / table.shift(1))
mean_returns = log_returns.mean()
cov_matrix = log_returns.cov()
num_portfolios = 25000
risk_free_rate = 0.0178

# Create an instance of the PortfolioOptimization class
portfolio = PortfolioOptimization(table)

# Call the methods of the class using the instance
portfolio.display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.23
# Annualised Volatility: 0.18
#
#
#              AAPL   COST    HD    LLY   MCD  NFLX  NVDA  TSLA    UNH
# allocation  10.59  20.35  2.56  30.14  8.32  4.35  4.65  7.68  11.36
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: 0.1
# Annualised Volatility: 0.13
#
#
#             ABBV  BABA  COST   JNJ    KO  LLY   MCD  MRK  NFLX   PEP   PFE  \
# allocation  0.03  2.77  2.82  16.2  9.93  1.4  14.4  2.8  0.45  0.99  3.45
#
#               PG     T     VZ    WMT   XOM
# allocation  9.94  0.04  19.31  15.13  0.33
